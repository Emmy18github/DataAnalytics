# %% [markdown]
# # Module 6 Exercises - Correlation and Models

# %% [markdown]
# ### Exercise 1:
#
# From the datasets folder, load the "tamiami.csv" file as a dataframe. Rename the columns (in order) to the following:
#
# - location
# - sales
# - employees
# - restaurants
# - foodcarts
# - price
#
# Then do a correlation table on that dataframe. What features (columns) are correlated? What features aren't correlated?

# %%
import pandas as pd
import numpy as np

Location = "datasets/tamiami.csv"
df=pd.read_csv(Location)

df.head()
# Out:
#    Cart Location  Hot Dog Sales  Employees in Nearby Office Buildings  \
# 0              1            100                                  1600
# 1              2             80                                  1200
# 2              3            450                                  2800
# 3              4            580                                  4300
# 4              5            100                                  1400
#
#    Num of Nearby Restaurants  Num of Other Food Carts Nearby  Price
# 0                          8                              12   4.16
# 1                          6                              13   4.63
# 2                         19                               6   0.50
# 3                         19                               2   0.47
# 4                          6                              13   4.24

# %%
#rename columns
df.rename(columns={'Cart Location': 'Location'}, inplace =True)
df.rename(columns={'Hot Dog Sales': 'Sales'}, inplace =True)
df.rename(columns={'Employees in Nearby Office Buildings': 'Employees'}, inplace =True)
df.rename(columns={'Num of Nearby Restaurants': 'Restaurants'}, inplace =True)
df.rename(columns={'Num of Other Food Carts Nearby': 'FoodCarts'}, inplace =True)
df.rename(columns={'Price': 'Price'}, inplace =True)
df.head()
# Out:
#    Location  Sales  Employees  Restaurants  FoodCarts  Price
# 0         1    100       1600            8         12   4.16
# 1         2     80       1200            6         13   4.63
# 2         3    450       2800           19          6   0.50
# 3         4    580       4300           19          2   0.47
# 4         5    100       1400            6         13   4.24

# %%
#creates a table of correlation values
df.corr()
# Out:
#              Location     Sales  Employees  Restaurants  FoodCarts     Price
# Location     1.000000  0.042705  -0.068923     0.049701   0.077219 -0.138444
# Sales        0.042705  1.000000   0.943238     0.913674  -0.919762 -0.966378
# Employees   -0.068923  0.943238   1.000000     0.856976  -0.874692 -0.881540
# Restaurants  0.049701  0.913674   0.856976     1.000000  -0.761793 -0.933951
# FoodCarts    0.077219 -0.919762  -0.874692    -0.761793   1.000000  0.860154
# Price       -0.138444 -0.966378  -0.881540    -0.933951   0.860154  1.000000

# %% [markdown]
# ### Exercise 2:
#
# Using the dataframe from the previous exercise, choose features (columns) to create a linear regression formula to predict sales. Try it with and without the y-intercept. How does it make a difference? Does adding or removing features in your model formula make a difference in the output?

# %%
import statsmodels.formula.api as smf

# %%
result = smf.ols('Location ~ Sales + Employees + Restaurants + FoodCarts + Price', data=df).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               Location   R-squared:                       0.300
# Model:                            OLS   Adj. R-squared:                  0.154
# Method:                 Least Squares   F-statistic:                     2.054
# Date:                Tue, 20 Aug 2019   Prob (F-statistic):              0.107
# Time:                        16:54:38   Log-Likelihood:                -101.97
# No. Observations:                  30   AIC:                             215.9
# Df Residuals:                      24   BIC:                             224.3
# Df Model:                           5
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept      36.9116     27.085      1.363      0.186     -18.990      92.813
# Sales           0.0361      0.061      0.590      0.561      -0.090       0.162
# Employees      -0.0058      0.006     -1.026      0.315      -0.017       0.006
# Restaurants    -1.4206      0.932     -1.524      0.141      -3.344       0.503
# FoodCarts       1.7469      1.000      1.748      0.093      -0.316       3.810
# Price          -7.9581      4.484     -1.775      0.089     -17.212       1.296
# ==============================================================================
# Omnibus:                        2.106   Durbin-Watson:                   0.683
# Prob(Omnibus):                  0.349   Jarque-Bera (JB):                1.545
# Skew:                           0.357   Prob(JB):                        0.462
# Kurtosis:                       2.147   Cond. No.                     4.11e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.11e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
#remove sales from regression, since it was not vwery correlated to other features
result = smf.ols('Location ~ Employees + Restaurants + FoodCarts + Price', data=df).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               Location   R-squared:                       0.290
# Model:                            OLS   Adj. R-squared:                  0.176
# Method:                 Least Squares   F-statistic:                     2.547
# Date:                Tue, 20 Aug 2019   Prob (F-statistic):             0.0644
# Time:                        16:58:42   Log-Likelihood:                -102.19
# No. Observations:                  30   AIC:                             214.4
# Df Residuals:                      25   BIC:                             221.4
# Df Model:                           4
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept      48.4557     18.493      2.620      0.015      10.370      86.542
# Employees      -0.0038      0.004     -0.851      0.403      -0.013       0.005
# Restaurants    -1.3083      0.901     -1.453      0.159      -3.163       0.546
# FoodCarts       1.4133      0.814      1.737      0.095      -0.262       3.089
# Price          -9.6895      3.347     -2.895      0.008     -16.583      -2.796
# ==============================================================================
# Omnibus:                        1.452   Durbin-Watson:                   0.670
# Prob(Omnibus):                  0.484   Jarque-Bera (JB):                1.157
# Skew:                           0.265   Prob(JB):                        0.561
# Kurtosis:                       2.197   Cond. No.                     2.81e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.81e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
#add sales back into formula
#remove y-intercept (set it to be 0)
result = smf.ols(formula='Location ~ Sales + Employees + Restaurants + FoodCarts + Price', data=df).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               Location   R-squared:                       0.300
# Model:                            OLS   Adj. R-squared:                  0.154
# Method:                 Least Squares   F-statistic:                     2.054
# Date:                Tue, 20 Aug 2019   Prob (F-statistic):              0.107
# Time:                        17:00:52   Log-Likelihood:                -101.97
# No. Observations:                  30   AIC:                             215.9
# Df Residuals:                      24   BIC:                             224.3
# Df Model:                           5
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept      36.9116     27.085      1.363      0.186     -18.990      92.813
# Sales           0.0361      0.061      0.590      0.561      -0.090       0.162
# Employees      -0.0058      0.006     -1.026      0.315      -0.017       0.006
# Restaurants    -1.4206      0.932     -1.524      0.141      -3.344       0.503
# FoodCarts       1.7469      1.000      1.748      0.093      -0.316       3.810
# Price          -7.9581      4.484     -1.775      0.089     -17.212       1.296
# ==============================================================================
# Omnibus:                        2.106   Durbin-Watson:                   0.683
# Prob(Omnibus):                  0.349   Jarque-Bera (JB):                1.545
# Skew:                           0.357   Prob(JB):                        0.462
# Kurtosis:                       2.147   Cond. No.                     4.11e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.11e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """
