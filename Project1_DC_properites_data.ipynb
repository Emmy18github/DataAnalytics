# %%
#import libraries
import pandas as pd
import numpy as np

#data visualization libraries
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#load DC_Properties.csv file with headers
dc_df = pd.read_csv("datasets/DC_Properties.csv", low_memory=False)

# %%
#explore top rows
dc_df.head()
# Out:
#    Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 0           0       4          0      Warm Cool  Y        2.0      8      4
# 1           1       3          1      Warm Cool  Y        2.0     11      5
# 2           2       3          1  Hot Water Rad  Y        2.0      9      5
# 3           3       3          1  Hot Water Rad  Y        2.0      8      5
# 4           4       2          1      Warm Cool  Y        1.0     11      3
#
#       AYB  YR_RMDL  ...  LONGITUDE  ASSESSMENT_NBHD ASSESSMENT_SUBNBHD  \
# 0  1910.0   1988.0  ... -77.040832       Old City 2   040 D Old City 2
# 1  1898.0   2007.0  ... -77.040764       Old City 2   040 D Old City 2
# 2  1910.0   2009.0  ... -77.040678       Old City 2   040 D Old City 2
# 3  1900.0   2003.0  ... -77.040629       Old City 2   040 D Old City 2
# 4  1913.0   2012.0  ... -77.039361       Old City 2   040 D Old City 2
#
#    CENSUS_TRACT CENSUS_BLOCK    WARD  SQUARE          X          Y QUADRANT
# ...

# %%
#how many rows of data
len(dc_df)
# Out:
# 158957

# %%
#how many non-nulls 
dc_df.count()
# Out:
# Unnamed: 0            158957
# BATHRM                158957
# HF_BATHRM             158957
# HEAT                  158957
# AC                    158957
# NUM_UNITS             106696
# ROOMS                 158957
# BEDRM                 158957
# AYB                   158686
# YR_RMDL                80928
# EYB                   158957
# STORIES               106652
# SALEDATE              132187
# PRICE                  98216
# QUALIFIED             158957
# SALE_NUM              158957
# GBA                   106696
# BLDG_NUM              158957
# STYLE                 106696
# STRUCT                106696
# GRADE                 106696
# CNDTN                 106696
# EXTWALL               106696
# ROOF                  106696
# INTWALL               106696
# KITCHENS              106695
# FIREPLACES            158957
# USECODE               158957
# LANDAREA              158957
# GIS_LAST_MOD_DTTM     158957
# SOURCE                158957
# CMPLX_NUM              52261
# ...

# %%
#drop duplicates
dc_df2 = dc_df.drop_duplicates()

# %%
#number of rows the same - no duplicates
len(dc_df2)
# Out:
# 158957

# %%
#Drop columns not needed

#AYB The earliest time the main portion of the building was built
#EYB The year an improvement was built more recent than actual year built
#GBA Gross building area in square feet
#BLDG_NUM Building Number on Property
#STYLE Style
#STRUCT Structure
#GRADE Grade
#EXTWALL Extrerior wall
#ROOF Roof type
#INTWALL Interior wall
#USECODE Property use code
#GIS_LAST_MOD_DTTM Last Modified Date
#SOURCE Raw Data Source
#CMPLX_NUM Complex number
#LIVING_GBA Gross building area in square feet
#NATIONALGRID Address location national grid coordinate spatial address
#LATITUDE Latitude
#LONGITUDE Longitude
#ASSESSMENT_SUBNBHD Subneighborhood ID
#CENSUS_TRACT Census tract
#CENSUS_BLOCK Census block
#SQUARE Square (from SSL)
#ASSESSMENT_NBHD Neighborhood ID
#WARD Ward (District is divided into eight wards, each with approximately 75,000 residents)
#X longitude
#Y latitude
#QUADRANT City quadrant (NE,SE,SW,NW)

dc_df2 = dc_df2.drop('AYB', axis=1)
dc_df2 = dc_df2.drop('EYB', axis=1)
dc_df2 = dc_df2.drop('GBA', axis=1)
dc_df2 = dc_df2.drop('BLDG_NUM', axis=1)
dc_df2 = dc_df2.drop('STYLE', axis=1)
dc_df2 = dc_df2.drop('STRUCT', axis=1)
dc_df2 = dc_df2.drop('GRADE', axis=1)
dc_df2 = dc_df2.drop('EXTWALL', axis=1)
dc_df2 = dc_df2.drop('ROOF', axis=1)
dc_df2 = dc_df2.drop('INTWALL', axis=1)
dc_df2 = dc_df2.drop('USECODE', axis=1)
dc_df2 = dc_df2.drop('GIS_LAST_MOD_DTTM', axis=1)
dc_df2 = dc_df2.drop('SOURCE', axis=1)
dc_df2 = dc_df2.drop('CMPLX_NUM', axis=1)
dc_df2 = dc_df2.drop('LIVING_GBA', axis=1)
dc_df2 = dc_df2.drop('NATIONALGRID', axis=1)
dc_df2 = dc_df2.drop('LATITUDE', axis=1)
dc_df2 = dc_df2.drop('LONGITUDE', axis=1)
dc_df2 = dc_df2.drop('ASSESSMENT_SUBNBHD', axis=1)
dc_df2 = dc_df2.drop('CENSUS_TRACT', axis=1)
dc_df2 = dc_df2.drop('CENSUS_BLOCK', axis=1)
dc_df2 = dc_df2.drop('SQUARE', axis=1)
dc_df2 = dc_df2.drop('ASSESSMENT_NBHD', axis=1)
dc_df2 = dc_df2.drop('WARD', axis=1)
dc_df2 = dc_df2.drop('X', axis=1)
dc_df2 = dc_df2.drop('Y', axis=1)
dc_df2 = dc_df2.drop('QUADRANT', axis=1)
dc_df2.head()
# Out:
#    Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 0           0       4          0      Warm Cool  Y        2.0      8      4
# 1           1       3          1      Warm Cool  Y        2.0     11      5
# 2           2       3          1  Hot Water Rad  Y        2.0      9      5
# 3           3       3          1  Hot Water Rad  Y        2.0      8      5
# 4           4       2          1      Warm Cool  Y        1.0     11      3
#
#    YR_RMDL  STORIES  ... QUALIFIED  SALE_NUM      CNDTN  KITCHENS FIREPLACES  \
# 0   1988.0      3.0  ...         Q         1       Good       2.0          5
# 1   2007.0      3.0  ...         U         1       Good       2.0          4
# 2   2009.0      3.0  ...         Q         3  Very Good       2.0          4
# 3   2003.0      3.0  ...         Q         1       Good       2.0          3
# 4   2012.0      3.0  ...         U         1       Good       1.0          0
#
# ...

# %%
#rename column to number
dc_df2.rename(columns={'Unnamed: 0':'NUMBER'}, inplace=True)

# %%
#set number column to index
dc_df2.set_index('NUMBER', inplace=True)

# %%
dc_df2.head()
# Out:
#         BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM  YR_RMDL  \
# NUMBER
# 0            4          0      Warm Cool  Y        2.0      8      4   1988.0
# 1            3          1      Warm Cool  Y        2.0     11      5   2007.0
# 2            3          1  Hot Water Rad  Y        2.0      9      5   2009.0
# 3            3          1  Hot Water Rad  Y        2.0      8      5   2003.0
# 4            2          1      Warm Cool  Y        1.0     11      3   2012.0
#
#         STORIES             SALEDATE  ...  QUALIFIED SALE_NUM      CNDTN  \
# NUMBER                                ...
# 0           3.0  2003-11-25 00:00:00  ...          Q        1       Good
# 1           3.0  2000-08-17 00:00:00  ...          U        1       Good
# 2           3.0  2016-06-21 00:00:00  ...          Q        3  Very Good
# 3           3.0  2006-07-12 00:00:00  ...          Q        1       Good
# 4           3.0                  NaN  ...          U        1       Good
#
# ...

# %%
dc_df2.count()
# Out:
# BATHRM         158957
# HF_BATHRM      158957
# HEAT           158957
# AC             158957
# NUM_UNITS      106696
# ROOMS          158957
# BEDRM          158957
# YR_RMDL         80928
# STORIES        106652
# SALEDATE       132187
# PRICE           98216
# QUALIFIED      158957
# SALE_NUM       158957
# CNDTN          106696
# KITCHENS       106695
# FIREPLACES     158957
# LANDAREA       158957
# FULLADDRESS    106040
# CITY           106051
# STATE          106051
# ZIPCODE        158956
# dtype: int64

# %%
#find rows where zipcode is 20009 - 13171 rows
dc_df2_20009 = dc_df2.loc[dc_df2['ZIPCODE']==20009]

# %%
print(dc_df2_20009)
# Out:
#         BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM  YR_RMDL  \
# NUMBER
# 0            4          0      Warm Cool  Y        2.0      8      4   1988.0
# 1            3          1      Warm Cool  Y        2.0     11      5   2007.0
# 2            3          1  Hot Water Rad  Y        2.0      9      5   2009.0
# 3            3          1  Hot Water Rad  Y        2.0      8      5   2003.0
# 4            2          1      Warm Cool  Y        1.0     11      3   2012.0
# 5            3          2  Hot Water Rad  Y        1.0     10      5      NaN
# 6            1          0      Warm Cool  Y        2.0      5      2   1988.0
# 7            3          1  Hot Water Rad  Y        2.0      8      4   2011.0
# 8            3          1      Warm Cool  Y        2.0      7      3   2008.0
# 9            1          1  Hot Water Rad  Y        1.0      6      2   1979.0
# 10           3          0     Forced Air  N        3.0     12      5   1950.0
# ...

# %%
#find rows in 20009 dataset where num_units = 1 (in 20009 zipcode)
dc_df2_20009 = dc_df2_20009.loc[dc_df2_20009['NUM_UNITS']==1]

# %%
print(dc_df2_20009)
# Out:
#         BATHRM  HF_BATHRM            HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# NUMBER
# 4            2          1       Warm Cool  Y        1.0     11      3
# 5            3          2   Hot Water Rad  Y        1.0     10      5
# 9            1          1   Hot Water Rad  Y        1.0      6      2
# 16           3          1       Warm Cool  Y        1.0      8      3
# 17           2          0   Hot Water Rad  N        1.0      6      3
# 20           3          1   Hot Water Rad  Y        1.0     14      5
# 22           1          0      Forced Air  Y        1.0      6      3
# 23           2          1      Forced Air  Y        1.0      5      3
# 24           2          1   Hot Water Rad  Y        1.0      8      3
# 25           1          0   Hot Water Rad  N        1.0      8      4
# 26           1          0   Hot Water Rad  N        1.0     10      5
# 32           2          1      Forced Air  Y        1.0      6      2
# ...

# %%
#dataframe now 20009 data with num_units =1
len(dc_df2_20009)
# Out:
# 1811

# %%
#drop rows with null data - now 1811 rows
dc_df2_20009_no_missing = dc_df2_20009.dropna()

# %%
#now 712 rows
print(dc_df2_20009_no_missing)
# Out:
#         BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM  YR_RMDL  \
# NUMBER
# 16           3          1      Warm Cool  Y        1.0      8      3   2006.0
# 20           3          1  Hot Water Rad  Y        1.0     14      5   2009.0
# 22           1          0     Forced Air  Y        1.0      6      3   2010.0
# 23           2          1     Forced Air  Y        1.0      5      3   2010.0
# 24           2          1  Hot Water Rad  Y        1.0      8      3   2004.0
# 25           1          0  Hot Water Rad  N        1.0      8      4   2010.0
# 32           2          1     Forced Air  Y        1.0      6      2   2004.0
# 72           4          2      Warm Cool  Y        1.0      8      3   2014.0
# 73           2          1      Warm Cool  Y        1.0      7      2   2011.0
# 89           2          1      Warm Cool  Y        1.0      6      2   1990.0
# 96           2          1      Warm Cool  Y        1.0      7      3   2004.0
# ...

# %%
dc_df2_20009_no_missing.columns
# Out:
# Index(['BATHRM', 'HF_BATHRM', 'HEAT', 'AC', 'NUM_UNITS', 'ROOMS', 'BEDRM',
#        'YR_RMDL', 'STORIES', 'SALEDATE', 'PRICE', 'QUALIFIED', 'SALE_NUM',
#        'CNDTN', 'KITCHENS', 'FIREPLACES', 'LANDAREA', 'FULLADDRESS', 'CITY',
#        'STATE', 'ZIPCODE'],
#       dtype='object')

# %%
dc_df2_20009_no_missing['PRICE'].max()
# Out:
# 8450000.0

# %%
dc_df2_20009_no_missing['PRICE'].min()
# Out:
# 250.0

# %%
#Standard Deviation Methold


dc_df2_20009_no_missing.head()

#dc_df2_20009_no_missing['Price'] = dc_df2_20009_no_missing['Price'].astype(float)
meanPRICE = dc_df2_20009_no_missing['PRICE'].mean()
stdPRICE = dc_df2_20009_no_missing['PRICE'].std()
toprange = meanPRICE + stdPRICE * 1.96
botrange = meanPRICE - stdPRICE * 1.96

newdf = dc_df2_20009_no_missing.copy()  #to not mess up the original df
newdf = newdf.drop(newdf[newdf['PRICE'] > toprange].index)
newdf = newdf.drop(newdf[newdf['PRICE'] < botrange].index)

newdf.head()
# Out:
#         BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM  YR_RMDL  \
# NUMBER
# 16           3          1      Warm Cool  Y        1.0      8      3   2006.0
# 20           3          1  Hot Water Rad  Y        1.0     14      5   2009.0
# 22           1          0     Forced Air  Y        1.0      6      3   2010.0
# 23           2          1     Forced Air  Y        1.0      5      3   2010.0
# 24           2          1  Hot Water Rad  Y        1.0      8      3   2004.0
#
#         STORIES             SALEDATE  ...  QUALIFIED SALE_NUM      CNDTN  \
# NUMBER                                ...
# 16          2.0  2010-11-04 00:00:00  ...          Q        1  Very Good
# 20          3.0  2016-01-12 00:00:00  ...          U        3  Very Good
# 22          2.0  2006-01-09 00:00:00  ...          Q        1       Good
# 23          2.0  2012-08-21 00:00:00  ...          Q        1  Very Good
# 24          2.0  2012-07-25 00:00:00  ...          Q        1       Good
#
# ...

# %%
print(meanPRICE)
# Out:
# 811010.6867977529

# %%
print(stdPRICE)
# Out:
# 529480.2067605866

# %%
newdf.corr()
# Out:
#               BATHRM  HF_BATHRM  NUM_UNITS     ROOMS     BEDRM   YR_RMDL  \
# BATHRM      1.000000   0.099487        NaN  0.540165  0.570187  0.151466
# HF_BATHRM   0.099487   1.000000        NaN  0.131554  0.090112  0.137078
# NUM_UNITS        NaN        NaN        NaN       NaN       NaN       NaN
# ROOMS       0.540165   0.131554        NaN  1.000000  0.707364  0.020836
# BEDRM       0.570187   0.090112        NaN  0.707364  1.000000  0.008202
# YR_RMDL     0.151466   0.137078        NaN  0.020836  0.008202  1.000000
# STORIES     0.441748   0.034399        NaN  0.484846  0.531291  0.040310
# PRICE       0.405587   0.213660        NaN  0.213858  0.236711  0.233497
# SALE_NUM    0.007169   0.053605        NaN -0.125506 -0.091077  0.147635
# KITCHENS    0.306312  -0.012133        NaN  0.258943  0.245945  0.035467
# FIREPLACES  0.184018   0.078573        NaN  0.250717  0.129028 -0.078202
# LANDAREA    0.385594   0.090203        NaN  0.433502  0.454035  0.024310
# ...

# %%
import statsmodels.formula.api as smf

# %%
#create linear regression to predict prices
result = smf.ols('PRICE ~ BEDRM + BATHRM + KITCHENS', data=newdf).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  PRICE   R-squared:                       0.169
# Model:                            OLS   Adj. R-squared:                  0.165
# Method:                 Least Squares   F-statistic:                     46.46
# Date:                Wed, 21 Aug 2019   Prob (F-statistic):           2.41e-27
# Time:                        16:40:49   Log-Likelihood:                -9806.4
# No. Observations:                 691   AIC:                         1.962e+04
# Df Residuals:                     687   BIC:                         1.964e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   2.946e+05   6.15e+04      4.786      0.000    1.74e+05    4.15e+05
# ...

# %%
#remove y-intercept (set it to be 0)
result = smf.ols('PRICE ~ BEDRM + BATHRM + KITCHENS -1', data=newdf).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  PRICE   R-squared:                       0.824
# Model:                            OLS   Adj. R-squared:                  0.823
# Method:                 Least Squares   F-statistic:                     1074.
# Date:                Wed, 21 Aug 2019   Prob (F-statistic):          4.75e-259
# Time:                        16:40:55   Log-Likelihood:                -9817.7
# No. Observations:                 691   AIC:                         1.964e+04
# Df Residuals:                     688   BIC:                         1.965e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# BEDRM       2.292e+04   1.39e+04      1.646      0.100   -4413.265    5.03e+04
# ...

# %%
#make a scatterplot
sns.lmplot(x='BEDRM', y='PRICE', data=newdf)

# %%
#boxplot showing stats for each characteristic
plt.subplots(figsize=(13,7))
sns.boxplot(data=newdf)

# %%
#change size of plot
plt.subplots(figsize=(13,7))

#violin plot shows the distribution of each type
sns.violinplot(x='BEDRM', y='PRICE', data=newdf)

# %%
#swarm plot
sns.swarmplot(x='BEDRM', y='PRICE', data=newdf)

# %%
#show correlation of stats via heatmap
corr = newdf.corr()

sns.heatmap(corr,vmin=-1, annot=True)

# %%
#create a histogram of the distribution
sns.distplot(newdf['PRICE'])
